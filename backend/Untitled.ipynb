# %%
import sqlite3
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
connection = sqlite3.connect('store.db')
# %load_ext sql
# %sql sqlite:///store.db

# %%
# %%sql
# SELECT * FROM Users
# Out:
#  * sqlite:///store.db
# Done.
# [(12, '5b854b61-6c53-487a-98b9-d9c25852e72e.jpg', 'Иван', 'Берсенев', 'сгл', 'почта@почта.ru', '79233692550', 1, 'login', 'password'),
#  (14, '8c3cf03f-eeb4-417b-9e5b-8e66b435c46b.jpg', 'БК', 'ПАРИ', 'ООО «БК «ПАРИ». Адрес места нахождения 142214, Московская область, г. Серпухов, ул. Ворошилова, д. 147 стр. 1, этаж 2 помещ. 1', 'support@pari.ru', '8-800-770-73-71', 0, 'pari', 'pari'),
#  (15, 'c89ddc16-51a1-404f-bf83-55bbd449b4b9.jpg', 'Магжан', 'Мязов', 'ТОО СГЛ Республика Казахстан, г.Алматы, мкрн. Ерменсай, ул. Жангир хана 1, индекс 050000', 'magzhanmyazov@gmail.com', '7-902-921-22-20', 1, 'magzhan', 'magzhan')]

# %%
# %%sql
# SELECT * FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [(5, '0433c74b-1ae0-4e67-a7eb-f85e0bded07d.png', 'Blast.tv Austin Major 2025', 'Blast.tv Austin Major 2025', 'Blast.tv Austin Major 2025', 'Киберспортивное мероприятие представляет собой захватывающее соревнование, собирающее лучших киберспортсменов на одной площадке...', 'A cyber sports event is an exciting competition that gathers the best esports athletes on one platform...', 'Кибер-спорттық іс-шараға қол жеткізу үшін ең жақын мекенжайда ең еңбекар электронды спортшылдарды жинаушы бір көшедай кездеседі...', 'Blast', 'Valve', 'Austin, USA', 'Austin, USA', 'Austin, USA', 'CS2', 1748908800000, 1750550400000, 1250000),
#  (6, '83516a77-087a-41ce-a548-0c4d08070a55.png', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Valve', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'CS2', 1755648000000, 1755993600000, 1250000),
#  (7, 'd8c4e737-981e-4c68-84ce-671b922eb955.png', 'PGL Belgrade 2025', 'PGL Belgrade 2025', 'PGL Belgrade 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'PGL', 'Valve', 'Belgrade, Serbia', 'Belgrade, Serbia', 'Belgrade, Serbia', 'CS2', 1761350400000, 1764633600000, 625000),
#  (8, '04d08e82-aae7-481e-9a69-eb6f250518e2.png', 'Intel Extreme Masters Chengdu 2025', 'Intel Extreme Masters Chengdu 2025', 'Intel Extreme Masters Chengdu 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Valve', 'Chengdu, China', 'Chengdu, China', 'Chengdu, China', 'CS2', 1762128000000, 1762646400000, 300000),
#  (9, '9e0185fe-e01b-4057-9487-fe9123fc863b.png', 'BLAST Rivals Fall 2025', 'BLAST Rivals Fall 2025', 'BLAST Rivals Fall 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Blast', 'Valve', 'TBA', 'TBA', 'TBA', 'CS2', 1762905600000, 1763251200000, 350000),
#  (10, 'a0e54b48-27e0-423b-acf5-644b7b5ce666.png', 'CS2 Major Championship Winter 2025', 'CS2 Major Championship Winter 2025', 'CS2 Major Championship Winter 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Valve', 'Valve', 'TBA', 'TBA', 'TBA', 'CS2', 1728000000, 1728000000, 1250000),
#  (11, '4ce8aef6-4581-4571-ab8b-830a553e6a56.png', 'ESL One Raleigh 2025', 'ESL One Raleigh 2025', 'ESL One Raleigh 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Valve', 'Raleigh, USA', 'Raleigh, USA', 'Raleigh, USA', 'Dota 2', 1728000000, 1728000000, 1000000),
#  (12, '92be3349-3401-46d4-9e36-7f573938406e.png', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Valve', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Dota 2', 1728000000, 1728000000, 1250000),
#  (13, '82a0c37d-eb72-4c94-9261-9a484830873b.png', 'BLAST Slam IV', 'BLAST Slam IV', 'BLAST Slam IV', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Blast', 'Valve', 'TBA', 'TBA', 'TBA', 'Dota 2', 1728000000, 1728000000, 1000000),
#  (14, '6e9de276-4a1a-4471-b0f3-4b3fdb984448.png', 'PGL Wallachia Season 5', 'PGL Wallachia Season 5', 'PGL Wallachia Season 5', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'PGL', 'Valve', 'Bucharest, Romania', 'Bucharest, Romania', 'Bucharest, Romania', 'Dota 2', 1728000000, 1728000000, 1000000),
#  (15, '270e428c-317c-4b72-985d-57b89bcd7960.png', 'The International 2025', 'The International 2025', 'The International 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Valve', 'Valve', 'Hamburg, Germany', 'Hamburg, Germany', 'Hamburg, Germany', 'Dota 2', 1728000000, 1728000000, 1000000),
#  (16, '5a40fe10-9cfb-4777-b5a6-b250c8e9da80.png', 'ePremier League 2025 - Finals', 'ePremier League 2025 - Finals', 'ePremier League 2025 - Finals', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'EA, Premier League', 'EA SPORTS', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'EA SPORTS FC 25', 1728000000, 1728000000, 130000),
#  (17, '7dfd64c1-aad8-44e0-918f-472a2175bc1b.png', 'eLibertadores 2025', 'eLibertadores 2025', 'eLibertadores 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'EA, CONMEBOL', 'EA SPORTS', 'São Paulo, Brazil', 'São Paulo, Brazil', 'São Paulo, Brazil', 'EA SPORTS FC 25', 1728000000, 1728000000, 106000),
#  (18, '3ffc5814-87d0-49c6-a6ba-90baf68bf340.png', 'MPL Indonesia Season 15', 'MPL Indonesia Season 15', 'MPL Indonesia Season 15', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Moonton, Mineski Indonesia', 'Moonton', 'Jakarta, Indonesia', 'Jakarta, Indonesia', 'Jakarta, Indonesia', 'MLBB', 1728000000, 1728000000, 299000),
#  (19, '56cd4c90-6390-425c-bf72-32fed94b8f61.png', 'ESL Snapdragon Pro Series: Mobile Masters 2025', 'ESL Snapdragon Pro Series: Mobile Masters 2025', 'ESL Snapdragon Pro Series: Mobile Masters 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Moonton', 'Jakarta, Indonesia', 'Jakarta, Indonesia', 'Jakarta, Indonesia', 'MLBB', 1728000000, 1728000000, 200000),
#  (20, 'eac36e05-e26f-4d9a-9c5c-2121b72adea2.png', 'MLBB Mid Season Cup 2025', 'MLBB Mid Season Cup 2025', 'MLBB Mid Season Cup 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Moonton, Esports World Cup Foundation, Hero Esports', 'Moonton', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'MLBB', 1728000000, 1728000000, 1000000),
#  (21, 'f3f485a9-0648-4c1f-87ab-d11b5af12f3f.png', 'RC World Tour 2024 Finals - GGST', 'RC World Tour 2024 Finals - GGST', 'RC World Tour 2024 Finals - GGST', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Arc System Works', 'Arc System Works', 'Los Angeles, USA', 'Los Angeles, USA', 'Los Angeles, USA', 'Guilty Gear -STRIVE-', 1728000000, 1728000000, 100000),
#  (22, 'e470335d-8443-4b15-b0d3-5419b6b216f8.png', 'ARC World Tour 2024 Finals - UNI2', 'ARC World Tour 2024 Finals - UNI2', 'ARC World Tour 2024 Finals - UNI2', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Arc System Works', 'French-Bread', 'Los Angeles, USA', 'Los Angeles, USA', 'Los Angeles, USA', 'Under Night In-Birth II', 1728000000, 1728000000, 50000),
#  (23, 'edb90da7-88b0-4bff-9893-70ae7c0c17c2.png', 'ARC World Tour 2024 Finals - GBVSR', 'ARC World Tour 2024 Finals - GBVSR', 'ARC World Tour 2024 Finals - GBVSR', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Arc System Works', 'Arc System Works', 'Los Angeles, USA', 'Los Angeles, USA', 'Los Angeles, USA', 'Granblue Fantasy Versus: Rising', 1728000000, 1728000000, 100000),
#  (24, 'acccdde2-66d6-4865-8f29-5ba702efde26.png', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Esports World Cup 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'ESL FACEIT Group', 'Ubisoft', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', 'Riyadh, Saudi Arabia', "Tom Clancy's Rainbow Six Siege", 1728000000, 1728000000, 1000000),
#  (25, '4e199a1e-9144-41f9-99b4-892ebd64c74d.png', 'BLAST R6 Major 2025', 'BLAST R6 Major 2025', 'BLAST R6 Major 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'BLAST', 'Ubisoft', 'TBA', 'TBA', 'TBA', "Tom Clancy's Rainbow Six Siege", 1728000000, 1728000000, 1000000),
#  (26, 'f5ce9ba0-d723-4533-9341-e0dace5fcbc4.png', 'PUBG Mobile Global Open 2025', 'PUBG Mobile Global Open 2025', 'PUBG Mobile Global Open 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'KRAFTON, Level Infinite, NODWIN Gaming', 'LightSpeed & Quantum Studio', 'Tashkent, Uzbekistan', 'Tashkent, Uzbekistan', 'Tashkent, Uzbekistan', 'PUBG Mobile', 1728000000, 1728000000, 409000),
#  (27, '27af0f4c-3e18-45a0-a92f-97f230e14173.png', 'Peacekeeper Elite League Spring 2025', 'Peacekeeper Elite League Spring 2025', 'Peacekeeper Elite League Spring 2025', 'Киберспортивное мероприятие...', 'A cyber sports event...', 'Кибер-спорттық іс-шара...', 'Tencent Games, Hero Esports', 'LightSpeed & Quantum Studio', 'Chengdu, China', 'Chengdu, China', 'Chengdu, China', 'PUBG Mobile', 1728000000, 1728000000, 2294640),
#  (28, 'f4474e3b-9559-46e8-a11c-81f75fb7be1f.png', 'fdgd', 'dfg', 'dfg', 'dfg', 'dfg', 'fddf', 'dfg', 'dfg', 'df', 'dfg', 'dfg', 'dfgsdg', 1751328000000, 1751673600000, 2342534534)]

# %%
# %%sql
# UPDATE Events
# SET previewPhoto = "previewPhoto",
#     nameRu = "nameRu",
#     nameEn = "nameEn",
#     nameKz = "nameKz",
#     descriptionRu = "descriptionRu",
#     descriptionEn = "descriptionEn",
#     descriptionKz = "descriptionKz",
#     manager = "manager",
#     placeRu = "placeRu",
#     placeEn = "placeEn",
#     placeKz = "placeKz",
#     discipline = "discipline",
#     startTime = 1,
#     endTime = 2,
#     prize = 3
# WHERE id = 5;
# Out:
#  * sqlite:///store.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Events
# WHERE
#         discipline IN ("вап","disc")
#     AND manager IN ("org")
#     AND developer IN ("dev")
#     AND prize BETWEEN 0 AND 100
#     AND startTime >= 0
#     AND endTime <= 10
#     AND (nameRu LIKE "%f%" OR nameEn LIKE "%f%" OR nameKz LIKE "%f%")
# Out:
#  * sqlite:///store.db
# Done.
# []

# %%
# %%sql
# SELECT DISTINCT manager FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [('Blast',),
#  ('ESL FACEIT Group',),
#  ('PGL',),
#  ('Valve',),
#  ('EA, Premier League',),
#  ('EA, CONMEBOL',),
#  ('Moonton, Mineski Indonesia',),
#  ('Moonton, Esports World Cup Foundation, Hero Esports',),
#  ('Arc System Works',),
#  ('BLAST',),
#  ('KRAFTON, Level Infinite, NODWIN Gaming',),
#  ('Tencent Games, Hero Esports',),
#  ('dfg',)]

# %%
# %%sql
# SELECT DISTINCT developer FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [('Valve',),
#  ('EA SPORTS',),
#  ('Moonton',),
#  ('Arc System Works',),
#  ('French-Bread',),
#  ('Ubisoft',),
#  ('LightSpeed & Quantum Studio',),
#  ('dfg',)]

# %%
# %%sql
# SELECT DISTINCT discipline FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [('вап',), ('disc',)]

# %%
# %%sql
# INSERT INTO Events (
#     previewPhoto, nameRu, nameEn, nameKz, descriptionRu, descriptionEn, descriptionKz, manager, developer, placeRu, placeEn, placeKz, discipline, startTime, endTime, prize) VALUES
# (
#     "defaultimg.png",
#     "Название 3",
#     "Name",
#     "NameKz",
#     "Киберспортивное мероприятие представляет собой захватывающее соревнование, собирающее лучших киберспортсменов на одной площадке. Участники сражаются в захватывающих игровых дисциплинах, проявляя невероятные навыки и смекалку. Мероприятие окутано атмосферой напряжения и волнения, погружая зрителей в мир электронного спорта. Победители получают не только почет и признание, но и щедрые призы и награды, становясь героями среди любителей киберспорта. Соревнующиеся демонстрируют стратегическое мышление, реакцию, слаженность команды и индивидуальное мастерство в зрелищных поединках. Каждый матч - это уникальное шоу, наполненное энергией и адреналином, приводящее к ошеломляющим результатам и превосходным игровым моментам. Киберспортивное мероприятие - это синтез профессионализма, азарта и страсти, привлекающий тысячи поклонников по всему миру.",
#     "A cyber sports event is an exciting competition that gathers the best esports athletes on one platform. Participants compete in thrilling gaming disciplines, showcasing incredible skills and cunning. The event is surrounded by an atmosphere of tension and excitement, immersing spectators in the world of electronic sports. Winners receive not only honor and recognition but also generous prizes and rewards, becoming heroes among esports enthusiasts. Competitors demonstrate strategic thinking, reflexes, team coordination, and individual mastery in spectacular matches. Each match is a unique show filled with energy and adrenaline, leading to stunning results and outstanding gameplay moments. A cyber sports event is a synthesis of professionalism, thrill, and passion, attracting thousands of fans worldwide.",
#     "Кибер-спорттық іс-шараға қол жеткізу үшін ең жақын мекенжайда ең еңбекар электронды спортшылдарды жинаушы бір көшедай кездеседі. Қатысушылар үміткерлік ойын дисциплиналарында ойыншылық қабілеттерін көрсетуді мақсатында кездесуде. Іс-шара жағдайысы жаманыат тауыпсыздың және толғануы сезім алу орта жасайды, келесілерді электронды спорттық әлемдің мазмұны арасында түнгендейді. Жеңшілер танымал дейіндер және анықталу, ал ескертулер мен марапатты шығушылар алу, спортшылар бекітілген мәчтеменің оқиғалық ойын мезетінде мекендейді. Әр маҧас - бұл энергия мен адреналинмен толтырылған күйірме, потенциалды нәтижелерге және шабуылды ойын ағзаларына бастаған жағдайды. Кибер-спорттық жеміс - бүйрайтындылық, эрзінділік пен махаббаттың синтезі, жалпы ертегілер салғыштырған, миллиондаған турар жамандарды ауыстыру.",
#     "Manager",
#     "CS:GO",
#     "Москва",
#     "Moscow",
#     "Москва КЗ",
#     "Dota",
#     1749004863,
#     1749264063,
#     10000
# )
# Out:
#  * sqlite:///store.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT manager, developer FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Organizator', 'Valve'),
#  ('Manager', 'CS:GO'),
#  ('Manager', 'CS:GO'),
#  ('Manager', 'CS:GO')]

# %%
# %%sql
# SELECT * FROM Users WHERE login = 'админ' AND password = 'админ'
# Out:
#  * sqlite:///store.db
# Done.
# [(9, 'daf6d6a3-56a0-4b8c-9b97-95e36760c9f7.png', 'админ', 'админыч', 'company', 'poschta', '78880009876', 1, 'админ', 'админ')]

# %%
# %%sql
# SELECT * FROM Sales
# Out:
#  * sqlite:///store.db
# Done.
# [(3, 0, 0, 0)]

# %%
# %%sql
# INSERT INTO Sales (eventId, userId, date) VALUES
# (1,11,123456)
# Out:
#  * sqlite:///store.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT Events.id, previewPhoto, nameRu, nameEn, nameKz, descriptionRu, descriptionEn, descriptionKz, manager, developer, placeRu, placeEn, placeKz, discipline, startTime, endTime, prize FROM Sales
# JOIN Events ON Events.id = eventId
# WHERE userId = 1
# Out:
#  * sqlite:///store.db
# Done.
# [(1, '1fc1d278-5c87-4b61-8384-9d3947089488.png', 'Название RU', 'Название EN', 'Название KZ', 'Название RU', 'Название RU', 'Название RU', 'Организатор', 'Разраб', 'москва', 'мосвка', 'москва', 'ксго', 1751328000000, 1751414400000, 1000006)]

# %%
# %%sql
# DELETE FROM Sales
# WHERE userId = 1 AND eventId = 1
# Out:
#  * sqlite:///store.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Users
# Out:
#  * sqlite:///store.db
# Done.
# [(11, '71a78480-c1a7-4c8f-b2f2-a10baddd60ef.png', 'имя1342', 'фамилия234234', 'Компания', 'sdfsd', '799123124', 1, 'логин', 'пароль')]

# %%
# %%sql
# SELECT * FROM Events
# Out:
#  * sqlite:///store.db
# Done.
# [(1, '1fc1d278-5c87-4b61-8384-9d3947089488.png', 'Название RU', 'Название EN', 'Название KZ', 'Название RU', 'Название RU', 'Название RU', 'Организатор', 'Разраб', 'москва', 'мосвка', 'москва', 'ксго', 1751328000000, 1751414400000, 1000006)]

# %%
# %%sql
# SELECT * FROM Sales
# Out:
#  * sqlite:///store.db
# Done.
# [(3, 0, 0, 0), (6, 1, 11, 123456)]

# %%
# %%sql
# INSERT INTO Events (
#     previewPhoto, nameRu, nameEn, nameKz, descriptionRu, descriptionEn, descriptionKz, manager, developer, placeRu, placeEn, placeKz, discipline, startTime, endTime, prize) VALUES
# -- CS2 Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Blast.tv Austin Major 2025",
#     "Blast.tv Austin Major 2025",
#     "Blast.tv Austin Major 2025",
#     "Киберспортивное мероприятие представляет собой захватывающее соревнование, собирающее лучших киберспортсменов на одной площадке...",
#     "A cyber sports event is an exciting competition that gathers the best esports athletes on one platform...",
#     "Кибер-спорттық іс-шараға қол жеткізу үшін ең жақын мекенжайда ең еңбекар электронды спортшылдарды жинаушы бір көшедай кездеседі...",
#     "Blast",
#     "Valve",
#     "Austin, USA",
#     "Austin, USA",
#     "Austin, USA",
#     "CS2",
#     1748894552,
#     1750536152,
#     1250000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Valve",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "CS2",
#     1755648000,
#     1755993600,
#     1250000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "PGL Belgrade 2025",
#     "PGL Belgrade 2025",
#     "PGL Belgrade 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "PGL",
#     "Valve",
#     "Belgrade, Serbia",
#     "Belgrade, Serbia",
#     "Belgrade, Serbia",
#     "CS2",
#     1761350400,
#     1762128000,
#     625000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Intel Extreme Masters Chengdu 2025",
#     "Intel Extreme Masters Chengdu 2025",
#     "Intel Extreme Masters Chengdu 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Valve",
#     "Chengdu, China",
#     "Chengdu, China",
#     "Chengdu, China",
#     "CS2",
#     1762128000,
#     1762732800,
#     300000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "BLAST Rivals Fall 2025",
#     "BLAST Rivals Fall 2025",
#     "BLAST Rivals Fall 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Blast",
#     "Valve",
#     "TBA",
#     "TBA",
#     "TBA",
#     "CS2",
#     1762905600,
#     1763251200,
#     350000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "CS2 Major Championship Winter 2025",
#     "CS2 Major Championship Winter 2025",
#     "CS2 Major Championship Winter 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Valve",
#     "Valve",
#     "TBA",
#     "TBA",
#     "TBA",
#     "CS2",
#     1764547200,
#     1765737600,
#     1250000
# ),
#
# -- Dota 2 Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "ESL One Raleigh 2025",
#     "ESL One Raleigh 2025",
#     "ESL One Raleigh 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Valve",
#     "Raleigh, USA",
#     "Raleigh, USA",
#     "Raleigh, USA",
#     "Dota 2",
#     1743984000,
#     1744502400,
#     1000000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Valve",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Dota 2",
#     1748894552,
#     1750536152,
#     1250000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "BLAST Slam IV",
#     "BLAST Slam IV",
#     "BLAST Slam IV",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Blast",
#     "Valve",
#     "TBA",
#     "TBA",
#     "TBA",
#     "Dota 2",
#     1762646400,
#     1762646400,
#     1000000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "PGL Wallachia Season 5",
#     "PGL Wallachia Season 5",
#     "PGL Wallachia Season 5",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "PGL",
#     "Valve",
#     "Bucharest, Romania",
#     "Bucharest, Romania",
#     "Bucharest, Romania",
#     "Dota 2",
#     1763164800,
#     1763932800,
#     1000000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "The International 2025",
#     "The International 2025",
#     "The International 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Valve",
#     "Valve",
#     "Hamburg, Germany",
#     "Hamburg, Germany",
#     "Hamburg, Germany",
#     "Dota 2",
#     1756944000,
#     1757894400,
#     1000000
# ),
#
# -- EA SPORTS FC 25 Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "ePremier League 2025 - Finals",
#     "ePremier League 2025 - Finals",
#     "ePremier League 2025 - Finals",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "EA, Premier League",
#     "EA SPORTS",
#     "United Kingdom",
#     "United Kingdom",
#     "United Kingdom",
#     "EA SPORTS FC 25",
#     1709251200,
#     1711152000,
#     130000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "eLibertadores 2025",
#     "eLibertadores 2025",
#     "eLibertadores 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "EA, CONMEBOL",
#     "EA SPORTS",
#     "São Paulo, Brazil",
#     "São Paulo, Brazil",
#     "São Paulo, Brazil",
#     "EA SPORTS FC 25",
#     1714694400,
#     1714780800,
#     106000
# ),
#
# -- MLBB Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "MPL Indonesia Season 15",
#     "MPL Indonesia Season 15",
#     "MPL Indonesia Season 15",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Moonton, Mineski Indonesia",
#     "Moonton",
#     "Jakarta, Indonesia",
#     "Jakarta, Indonesia",
#     "Jakarta, Indonesia",
#     "MLBB",
#     1709769600,
#     1717632000,
#     299000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "ESL Snapdragon Pro Series: Mobile Masters 2025",
#     "ESL Snapdragon Pro Series: Mobile Masters 2025",
#     "ESL Snapdragon Pro Series: Mobile Masters 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Moonton",
#     "Jakarta, Indonesia",
#     "Jakarta, Indonesia",
#     "Jakarta, Indonesia",
#     "MLBB",
#     1743984000,
#     1744502400,
#     200000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "MLBB Mid Season Cup 2025",
#     "MLBB Mid Season Cup 2025",
#     "MLBB Mid Season Cup 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Moonton, Esports World Cup Foundation, Hero Esports",
#     "Moonton",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "MLBB",
#     1751328000,
#     1754006400,
#     1000000
# ),
#
# -- Fighting Games Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "RC World Tour 2024 Finals - GGST",
#     "RC World Tour 2024 Finals - GGST",
#     "RC World Tour 2024 Finals - GGST",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Arc System Works",
#     "Arc System Works",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Guilty Gear -STRIVE-",
#     1710979200,
#     1711152000,
#     100000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "ARC World Tour 2024 Finals - UNI2",
#     "ARC World Tour 2024 Finals - UNI2",
#     "ARC World Tour 2024 Finals - UNI2",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Arc System Works",
#     "French-Bread",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Under Night In-Birth II",
#     1710979200,
#     1711152000,
#     50000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "ARC World Tour 2024 Finals - GBVSR",
#     "ARC World Tour 2024 Finals - GBVSR",
#     "ARC World Tour 2024 Finals - GBVSR",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Arc System Works",
#     "Arc System Works",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Los Angeles, USA",
#     "Granblue Fantasy Versus: Rising",
#     1710979200,
#     1711152000,
#     100000
# ),
#
# -- Rainbow Six Siege Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Esports World Cup 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "ESL FACEIT Group",
#     "Ubisoft",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Riyadh, Saudi Arabia",
#     "Tom Clancy's Rainbow Six Siege",
#     1755648000,
#     1755993600,
#     1000000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "BLAST R6 Major 2025",
#     "BLAST R6 Major 2025",
#     "BLAST R6 Major 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "BLAST",
#     "Ubisoft",
#     "TBA",
#     "TBA",
#     "TBA",
#     "Tom Clancy's Rainbow Six Siege",
#     1762905600,
#     1763251200,
#     1000000
# ),
#
# -- PUBG Mobile Events
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "PUBG Mobile Global Open 2025",
#     "PUBG Mobile Global Open 2025",
#     "PUBG Mobile Global Open 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "KRAFTON, Level Infinite, NODWIN Gaming",
#     "LightSpeed & Quantum Studio",
#     "Tashkent, Uzbekistan",
#     "Tashkent, Uzbekistan",
#     "Tashkent, Uzbekistan",
#     "PUBG Mobile",
#     1744416000,
#     1744502400,
#     409000
# ),
# (
#     "ccd86755-8594-40b5-b7c5-3832f8506250.jpg",
#     "Peacekeeper Elite League Spring 2025",
#     "Peacekeeper Elite League Spring 2025",
#     "Peacekeeper Elite League Spring 2025",
#     "Киберспортивное мероприятие...",
#     "A cyber sports event...",
#     "Кибер-спорттық іс-шара...",
#     "Tencent Games, Hero Esports",
#     "LightSpeed & Quantum Studio",
#     "Chengdu, China",
#     "Chengdu, China",
#     "Chengdu, China",
#     "PUBG Mobile",
#     1708416000,
#     1715980800,
#     2294640
# );
# Out:
#  * sqlite:///store.db
# 23 rows affected.
# []
